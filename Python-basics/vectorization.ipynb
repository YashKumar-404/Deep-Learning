# %%
import numpy as np
a = np.arange(5)
print(a)
# Out:
# [0 1 2 3 4]

# %% [markdown]
# DOT PRODUCT

# %%
# fast
a = np.random.rand(5)
b = np.random.rand(5)
c = np.dot(a,b)
print(c)
# Out:
# 0.5063541875531966

# %%
# slow
dot_product = 0 
for i in range(5):
    dot_product += a[i]*b[i]
print(dot_product)
# Out:
# 0.5063541875531966
