# %%
import numpy as np
a = np.random.rand(5)
print(a)
# Out:
# [0.82687878 0.6655325  0.70485562 0.26614015 0.54547566]

# %%
print(a.shape)
# Out:
# (5,)

# %%
b = a.reshape(-1,1)
print(b)
# Out:
# [[0.82687878]
#  [0.6655325 ]
#  [0.70485562]
#  [0.26614015]
#  [0.54547566]]

# %%
print(np.dot(a,b))
# Out:
# [1.99185774]
